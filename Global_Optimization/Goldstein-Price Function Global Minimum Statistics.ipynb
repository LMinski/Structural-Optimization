# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
c = 0

# %%
#função
from multiprocessing.resource_sharer import stop

def goldstein_price(x):
    global c
    global sum
    sum = (1+((x[0]+x[1]+1)**2)*(19-14*x[0]+3*(x[0]**2)-14*x[1]+6*x[0]*x[1]+3*(x[1]**2)))*(30+((2*x[0]-3*x[1])**2)*(18-32*x[0]+12*(x[0]**2)+48*x[1]-36*x[0]*x[1]+27*(x[1])**2))
    global coordinates
    coordinates = [x[0], x[1]]
    if c > 50:
        return [sum] and sys.exit()
    c += 1
    return sum

# %%
#suposições dos pontos, utilização da função differential_evolution e plotagem da posição x e valor da função no ponto x1 e x2
from scipy.optimize import differential_evolution
from scipy.optimize import shgo
from scipy.optimize import dual_annealing
from scipy.optimize import dual_annealing
from scipy.optimize import direct
import numpy

results_de = []
results_shgo = []
results_da = []
results_direct = []
cost_de = []
cost_shgo = []
cost_da = []
cost_direct = []
coordinates_de = []
coordinates_shgo = []
coordinates_da = []
coordinates_direct = []

bounds = (-2, 2), (-2, 2)

for i in range (100):

    try: result = differential_evolution(goldstein_price, bounds)

    except:
        results_de.append(sum)
        coordinates_de.append([coordinates])
        cost_de.append(c)

    finally:
        results_de.append(sum)
        coordinates_de.append([coordinates])
        cost_de.append(c)
        c = 0

    try: result1 = shgo(goldstein_price, bounds)

    except:
        results_shgo.append(sum)
        coordinates_shgo.append([coordinates])
        cost_shgo.append(c)

    finally:
        results_shgo.append(sum)
        coordinates_shgo.append([coordinates])
        cost_shgo.append(c)

        c = 0

    try: result2 = dual_annealing(goldstein_price, bounds)

    except:
        results_da.append(sum)
        coordinates_da.append([coordinates])
        cost_da.append(c)

    finally:
        results_da.append(sum)
        coordinates_da.append([coordinates])
        cost_da.append(c)
        
    try: result3 = direct(goldstein_price, bounds)

    except:
        results_direct.append(sum)
        coordinates_direct.append([coordinates])
        cost_direct.append(c)

    finally:
        results_direct.append(sum)
        coordinates_direct.append([coordinates])
        cost_direct.append(c)

print("Differential Evolution")
print(f"Média de Reultados: {numpy.median(results_de)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_de)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_de)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_de)}")
print(f"Custo: {numpy.median(cost_de)}")

print("\n")

print("SHGO")
print(f"Média de Reultados: {numpy.median(results_shgo)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_shgo)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_shgo)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_shgo)}")
print(f"Custo: {numpy.median(cost_shgo)}")

print("\n")
print("Dual Annealing")
print(f"Média de Resultados: {numpy.median(results_da)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_da)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_da)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_da)}")
print(f"Custo: {numpy.median(cost_da)}")

print("\n")
print("Direct")
print(f"Média de Resultados: {numpy.median(results_direct)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_direct)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_direct)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_direct)}")
print(f"Custo: {numpy.median(cost_direct)}")
# Out:
# Differential Evolution
# Média de Reultados: 6061.847465143252
# Desvio Padrão de Resultados: 126280.62861420504
# Média de Coordenadas: 0.10534495486796303
# Desvio Padrão de Coordenadas: 1.1325624315638263
# Custo: 51.0
#
#
# SHGO
# Média de Reultados: 3.152241380815032
# Desvio Padrão de Resultados: 4.440892098500626e-16
# Média de Coordenadas: -0.5184902196890717
# Desvio Padrão de Coordenadas: 0.495042343005977
# Custo: 51.0
#
#
# Dual Annealing
# Média de Resultados: 30.000008468925596
# Desvio Padrão de Resultados: 12023.209999855246
# Média de Coordenadas: -0.14862261107517244
# Desvio Padrão de Coordenadas: 0.8790076529677089
# Custo: 51.0
#
#
# Direct
# Média de Resultados: 600.0
# Desvio Padrão de Resultados: 0.0
# Média de Coordenadas: 0.0
# Desvio Padrão de Coordenadas: 0.0
# Custo: 51.0

# %%
import pandas as pd

data = [['Differential_Evolution', numpy.median(results_de), numpy.std(results_de), numpy.median(coordinates_de), numpy.std(coordinates_de), numpy.median(cost_de)],
        ['SHGO', numpy.median(results_shgo), numpy.std(results_shgo), numpy.median(coordinates_shgo), numpy.std(coordinates_shgo), numpy.median(cost_shgo)],
        ['Dual Annealing', numpy.median(results_da), numpy.std(results_da), numpy.median(coordinates_da), numpy.std(coordinates_da), numpy.median(cost_da)],
        ['Direct', numpy.std(results_direct), numpy.std(results_direct), numpy.median(coordinates_direct), numpy.std(coordinates_direct), numpy.median(cost_direct)]]
columns_name = ['', 'Average Results', 'Standard Deviation Results', 'Average Coordinates', 'Standard Deviation Coordinate', 'Cost']
df = pd.DataFrame(data, columns = columns_name)
df = df.set_index([''])
df
# Out:
#                         Average Results  Standard Deviation Results  \
#
# Differential_Evolution      6061.847465                1.262806e+05
# SHGO                           3.152241                4.440892e-16
# Dual Annealing                30.000008                1.202321e+04
# Direct                         0.000000                0.000000e+00
#
#                         Average Coordinates  Standard Deviation Coordinate  \
#
# Differential_Evolution             0.105345                       1.132562
# SHGO                              -0.518490                       0.495042
# Dual Annealing                    -0.148623                       0.879008
# Direct                             0.000000                       0.000000
#
#                         Cost
#
# Differential_Evolution  51.0
# SHGO                    51.0
# Dual Annealing          51.0
# Direct                  51.0
