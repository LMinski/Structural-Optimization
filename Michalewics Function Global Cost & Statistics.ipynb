# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
c = 0

# %%
#função
def michalewicz_function(x):  
    global c
    global sum
    #d=2 
    #m = 10
    sum = -1 * ( (np.sin(x[0]) * np.sin((1 * x[0]**2) / np.pi)**20) + \
           (np.sin(x[1]) * np.sin((2 * x[1]**2) / np.pi)**20) )
    global coordinates
    coordinates = [x[0], x[1]]
    if c > 50:
       return [sum] and sys.exit()
    c += 1       
    return sum

# %%
#suposições dos pontos, utilização da função differential_evolution e plotagem da posição x e valor da função no ponto x1 e x2
from scipy.optimize import differential_evolution
from scipy.optimize import shgo
from scipy.optimize import dual_annealing
from scipy.optimize import direct
import numpy

results_de = []
results_shgo = []
results_da = []
results_direct = []
cost_de = []
cost_shgo = []
cost_da = []
cost_direct = []
coordinates_de = []
coordinates_shgo = []
coordinates_da = []
coordinates_direct = []

bounds = (0, np.pi), (0, np.pi)

for i in range (100):

    try: result = differential_evolution(michalewicz_function, bounds)

    except:
        results_de.append(sum)
        coordinates_de.append([coordinates])
        cost_de.append(c)

    finally:
        results_de.append(sum)
        coordinates_de.append([coordinates])
        cost_de.append(c)
        c = 0

    try: result1 = shgo(michalewicz_function, bounds)

    except:
        results_shgo.append(sum)
        coordinates_shgo.append([coordinates])
        cost_shgo.append(c)

    finally:
        results_shgo.append(sum)
        coordinates_shgo.append([coordinates])
        cost_shgo.append(c)

        c = 0

    try: result2 = dual_annealing(michalewicz_function, bounds)

    except:
        results_da.append(sum)
        coordinates_da.append([coordinates])
        cost_da.append(c)

    finally:
        results_da.append(sum)
        coordinates_da.append([coordinates])
        cost_da.append(c)
        
    try: result3 = direct(michalewicz_function, bounds)

    except:
        results_direct.append(sum)
        coordinates_direct.append([coordinates])
        cost_direct.append(c)

    finally:
        results_direct.append(sum)
        coordinates_direct.append([coordinates])
        cost_direct.append(c)

print("Differential Evolution")
print(f"Média de Reultados: {numpy.median(results_de)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_de)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_de)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_de)}")
print(f"Custo: {numpy.median(cost_de)}")

print("\n")

print("SHGO")
print(f"Média de Reultados: {numpy.median(results_shgo)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_shgo)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_shgo)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_shgo)}")
print(f"Custo: {numpy.median(cost_shgo)}")

print("\n")
print("Dual Annealing")
print(f"Média de Resultados: {numpy.median(results_da)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_da)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_da)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_da)}")
print(f"Custo: {numpy.median(cost_da)}")

print("\n")
print("Direct")
print(f"Média de Resultados: {numpy.median(results_direct)}")
print(f"Desvio Padrão de Resultados: {numpy.std(results_direct)}")
print(f"Média de Coordenadas: {numpy.median(coordinates_direct)}")
print(f"Desvio Padrão de Coordenadas: {numpy.std(coordinates_direct)}")
print(f"Custo: {numpy.median(cost_direct)}")
# Out:
# Differential Evolution
# Média de Reultados: -0.0004928383390969418
# Desvio Padrão de Resultados: 0.274899683176684
# Média de Coordenadas: 1.3964519362076353
# Desvio Padrão de Coordenadas: 0.9031289351412567
# Custo: 51.0
#
#
# SHGO
# Média de Reultados: -1.801303410098536
# Desvio Padrão de Resultados: 4.440892098500626e-16
# Média de Coordenadas: 1.8868509051874875
# Desvio Padrão de Coordenadas: 0.3160545850964046
# Custo: 40.0
#
#
# Dual Annealing
# Média de Resultados: -0.8008959861263358
# Desvio Padrão de Resultados: 0.686044693235561
# Média de Coordenadas: 1.9660704775009719
# Desvio Padrão de Coordenadas: 0.7644850178098
# Custo: 51.0
#
#
# Direct
# Média de Resultados: -1.0009765625
# Desvio Padrão de Resultados: 0.0
# Média de Coordenadas: 1.5707963267948966
# Desvio Padrão de Coordenadas: 0.0
# Custo: 51.0

# %%
import pandas as pd
df= pd.DataFrame(columns= ('Estatísticas', 'Differential Evolution', 'SHGO', 'Dual Annealing', 'Direct'))

# %%
df["Estatísticas"] = "Média", "Desvio Padrão", "Média das Coordenadas", "Desvio Padrão das Coordenadas", "Custo"

# %%
df["Differential Evolution"] = numpy.median(results_de), numpy.std(results_de), numpy.median(coordinates_de), numpy.std(coordinates_de), numpy.median(cost_de)
df["SHGO"] = numpy.median(results_shgo), numpy.std(results_shgo), numpy.median(coordinates_shgo), numpy.std(coordinates_shgo), numpy.median(cost_shgo)
df["Dual Annealing"] = numpy.median(results_da), numpy.std(results_da), numpy.median(coordinates_da), numpy.std(coordinates_da), numpy.median(cost_da)
df["Direct"] = numpy.median(results_direct), numpy.std(results_direct), numpy.median(coordinates_direct), numpy.std(coordinates_direct), numpy.median(cost_direct)

# %%
from pandas import DataFrame


def left_align(df: DataFrame):
    left_aligned_df = df.style.set_properties(**{'text-align': 'left'})
    left_aligned_df = left_aligned_df.set_table_styles(
        [dict(selector='th', props=[('text-align', 'left')])]
    )
    return left_aligned_df

left_align(df.head())
# Out:
# <style type="text/css">
# #T_35d2c th {
#   text-align: left;
# }
# #T_35d2c_row0_col0, #T_35d2c_row0_col1, #T_35d2c_row0_col2, #T_35d2c_row0_col3, #T_35d2c_row0_col4, #T_35d2c_row1_col0, #T_35d2c_row1_col1, #T_35d2c_row1_col2, #T_35d2c_row1_col3, #T_35d2c_row1_col4, #T_35d2c_row2_col0, #T_35d2c_row2_col1, #T_35d2c_row2_col2, #T_35d2c_row2_col3, #T_35d2c_row2_col4, #T_35d2c_row3_col0, #T_35d2c_row3_col1, #T_35d2c_row3_col2, #T_35d2c_row3_col3, #T_35d2c_row3_col4, #T_35d2c_row4_col0, #T_35d2c_row4_col1, #T_35d2c_row4_col2, #T_35d2c_row4_col3, #T_35d2c_row4_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_35d2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35d2c_level0_col0" class="col_heading level0 col0" >Estatísticas</th>
#       <th id="T_35d2c_level0_col1" class="col_heading level0 col1" >Differential Evolution</th>
#       <th id="T_35d2c_level0_col2" class="col_heading level0 col2" >SHGO</th>
#       <th id="T_35d2c_level0_col3" class="col_heading level0 col3" >Dual Annealing</th>
#       <th id="T_35d2c_level0_col4" class="col_heading level0 col4" >Direct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35d2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35d2c_row0_col0" class="data row0 col0" >Média</td>
#       <td id="T_35d2c_row0_col1" class="data row0 col1" >-0.000493</td>
#       <td id="T_35d2c_row0_col2" class="data row0 col2" >-1.801303</td>
#       <td id="T_35d2c_row0_col3" class="data row0 col3" >-0.800896</td>
#       <td id="T_35d2c_row0_col4" class="data row0 col4" >-1.000977</td>
#     </tr>
#     <tr>
#       <th id="T_35d2c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35d2c_row1_col0" class="data row1 col0" >Desvio Padrão</td>
#       <td id="T_35d2c_row1_col1" class="data row1 col1" >0.274900</td>
#       <td id="T_35d2c_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_35d2c_row1_col3" class="data row1 col3" >0.686045</td>
#       <td id="T_35d2c_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35d2c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35d2c_row2_col0" class="data row2 col0" >Média das Coordenadas</td>
#       <td id="T_35d2c_row2_col1" class="data row2 col1" >1.396452</td>
#       <td id="T_35d2c_row2_col2" class="data row2 col2" >1.886851</td>
#       <td id="T_35d2c_row2_col3" class="data row2 col3" >1.966070</td>
#       <td id="T_35d2c_row2_col4" class="data row2 col4" >1.570796</td>
#     </tr>
#     <tr>
#       <th id="T_35d2c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35d2c_row3_col0" class="data row3 col0" >Desvio Padrão das Coordenadas</td>
#       <td id="T_35d2c_row3_col1" class="data row3 col1" >0.903129</td>
#       <td id="T_35d2c_row3_col2" class="data row3 col2" >0.316055</td>
#       <td id="T_35d2c_row3_col3" class="data row3 col3" >0.764485</td>
#       <td id="T_35d2c_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35d2c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35d2c_row4_col0" class="data row4 col0" >Custo</td>
#       <td id="T_35d2c_row4_col1" class="data row4 col1" >51.000000</td>
#       <td id="T_35d2c_row4_col2" class="data row4 col2" >40.000000</td>
#       <td id="T_35d2c_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_35d2c_row4_col4" class="data row4 col4" >51.000000</td>
#     </tr>
#   </tbody>
# </table>
