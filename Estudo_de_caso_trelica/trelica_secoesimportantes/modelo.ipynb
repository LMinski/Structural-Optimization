# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
data = pd.read_excel(f"C:\\Users\\Leonardo\\Desktop\\Projetos Python\\Pesquisa\\trelica_secoes\\output_10.xlsx")

# %%
data = data.drop('Unnamed: 0', axis = 1)
data
# Out:
#    Section G0  Section G1  Section G2  Section G3  Section G4  Section G5  \
# 0    0.000308    0.000513    0.000513    0.000582    0.000349    0.000480
# 1    0.000471    0.000471    0.000349    0.000480    0.000480    0.000480
# 2    0.000582    0.000308    0.000480    0.000471    0.000379    0.000430
# 3    0.000513    0.000379    0.000480    0.000471    0.000389    0.000296
# 4    0.000631    0.000296    0.000430    0.000296    0.000513    0.000308
# 5    0.000471    0.000631    0.000430    0.000379    0.000235    0.000266
# 6    0.000349    0.000582    0.000513    0.000266    0.000471    0.000631
# 7    0.000582    0.000513    0.000430    0.000471    0.000513    0.000513
# 8    0.000296    0.000430    0.000266    0.000631    0.000389    0.000266
# 9    0.000296    0.000389    0.000349    0.000266    0.000389    0.000296
#
#    Section G6   Material G0   Material G1   Material G2  ...      Fy  \
# 0    0.000389  200000000000  200000000000  200000000000  ... -100000
# 1    0.000296  200000000000  200000000000  200000000000  ... -100000
# 2    0.000379  200000000000  200000000000  200000000000  ... -100000
# 3    0.000389  200000000000  200000000000  200000000000  ... -100000
# 4    0.000379  200000000000  200000000000  200000000000  ... -100000
# 5    0.000349  200000000000  200000000000  200000000000  ... -100000
# 6    0.000235  200000000000  200000000000  200000000000  ... -100000
# 7    0.000430  200000000000  200000000000  200000000000  ... -100000
# 8    0.000308  200000000000  200000000000  200000000000  ... -100000
# 9    0.000631  200000000000  200000000000  200000000000  ... -100000
#
#    desloc_x  desloc_y    Tension G0    Tension G1    Tension G2    Tension G3  \
# 0 -0.003110 -0.011874 -4.136637e+08 -5.342770e+07  3.364359e+08 -1.763918e+08
# 1 -0.002637 -0.013170 -3.190523e+08 -1.067381e+08  4.290153e+08 -1.465077e+08
# 2 -0.002376 -0.011181 -2.426191e+08 -1.337802e+08  3.308244e+08 -1.765386e+08
# 3 -0.003066 -0.011774 -2.752847e+08 -1.087626e+08  3.307895e+08 -1.764884e+08
# 4 -0.002863 -0.012013 -2.479463e+08 -1.907235e+08  3.338276e+08 -2.080512e+08
# 5 -0.003357 -0.013421 -2.953938e+08 -6.201345e+07  3.741151e+08 -2.271306e+08
# 6 -0.002946 -0.014521 -4.307997e+08 -8.651049e+07  2.917171e+08 -2.639736e+08
# 7 -0.002272 -0.010495 -2.595198e+08 -9.949425e+07  3.464173e+08 -1.470045e+08
# 8 -0.004255 -0.016168 -4.751407e+08 -9.451547e+07  5.990915e+08 -1.330355e+08
# 9 -0.004199 -0.013511 -5.020298e+08 -1.249379e+08  4.338085e+08 -2.732684e+08
#
#      Tension G4    Tension G5    Tension G6
# 0  1.110640e+08 -2.083333e+08  3.635510e+08
# 1  1.481201e+08 -2.083333e+08  4.777749e+08
# 2  1.537511e+08 -2.325581e+08  3.731434e+08
# 3  1.498595e+08 -3.378378e+08  3.635510e+08
# 4  1.556300e+08 -3.246753e+08  3.731434e+08
# 5  2.354845e+08 -3.759398e+08  4.052188e+08
# 6  1.511770e+08 -1.584786e+08  6.017930e+08
# 7  1.407061e+08 -1.949318e+08  3.288869e+08
# 8  1.477531e+08 -3.759398e+08  4.591602e+08
# 9  1.766888e+08 -3.378378e+08  2.241226e+08
#
# [10 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['Section G0', 'Section G1', 'Section G2', 'Section G3', 'Section G4',
#        'Section G5', 'Section G6', 'Material G0', 'Material G1', 'Material G2',
#        'Material G3', 'Material G4', 'Material G5', 'Material G6', 'Fx', 'Fy',
#        'desloc_x', 'desloc_y', 'Tension G0', 'Tension G1', 'Tension G2',
#        'Tension G3', 'Tension G4', 'Tension G5', 'Tension G6'],
#       dtype='object')

# %%
data = data.drop(['Material G0', 'Material G1', 'Material G2',
       'Material G3', 'Material G4', 'Material G5', 'Material G6', 'Fx','desloc_x', 'Tension G0', 'Tension G1', 'Tension G2',
       'Tension G3', 'Tension G4', 'Tension G5', 'Tension G6', 'Fy'], axis = 1)
data
# Out:
#    Section G0  Section G1  Section G2  Section G3  Section G4  Section G5  \
# 0    0.000308    0.000513    0.000513    0.000582    0.000349    0.000480
# 1    0.000471    0.000471    0.000349    0.000480    0.000480    0.000480
# 2    0.000582    0.000308    0.000480    0.000471    0.000379    0.000430
# 3    0.000513    0.000379    0.000480    0.000471    0.000389    0.000296
# 4    0.000631    0.000296    0.000430    0.000296    0.000513    0.000308
# 5    0.000471    0.000631    0.000430    0.000379    0.000235    0.000266
# 6    0.000349    0.000582    0.000513    0.000266    0.000471    0.000631
# 7    0.000582    0.000513    0.000430    0.000471    0.000513    0.000513
# 8    0.000296    0.000430    0.000266    0.000631    0.000389    0.000266
# 9    0.000296    0.000389    0.000349    0.000266    0.000389    0.000296
#
#    Section G6  desloc_y
# 0    0.000389 -0.011874
# 1    0.000296 -0.013170
# 2    0.000379 -0.011181
# 3    0.000389 -0.011774
# 4    0.000379 -0.012013
# 5    0.000349 -0.013421
# 6    0.000235 -0.014521
# 7    0.000430 -0.010495
# 8    0.000308 -0.016168
# 9    0.000631 -0.013511

# %%
x = data.drop('desloc_y', axis = 1)
y = data['desloc_y']

# %% [markdown]
# 10 EXEMPLOS

# %%
x_train_sm = sm.add_constant(x)
lr= sm.OLS(y,x_train_sm).fit()
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               desloc_y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     15.01
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):             0.0638
# Time:                        16:44:31   Log-Likelihood:                 70.053
# No. Observations:                  10   AIC:                            -124.1
# Df Residuals:                       2   BIC:                            -121.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0296      0.003     -9.621      0.011      -0.043      -0.016
# Section G0     9.1774      1.712      5.362      0.033       1.813      16.542
# Section G1     1.5190      2.301      0.660      0.577      -8.382      11.420
# Section G2     9.8111      3.433      2.858      0.104      -4.958      24.580
# Section G3     5.1685      1.527      3.385      0.077      -1.401      11.738
# Section G4     1.2697      3.847      0.330      0.773     -15.284      17.824
# Section G5     2.6993      2.860      0.944      0.445      -9.606      15.004
# Section G6    10.6198      1.912      5.555      0.031       2.394      18.845
# ==============================================================================
# Omnibus:                        1.636   Durbin-Watson:                   1.329
# Prob(Omnibus):                  0.441   Jarque-Bera (JB):                0.831
# Skew:                           0.682   Prob(JB):                        0.660
# Kurtosis:                       2.635   Cond. No.                     3.63e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\Leonardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\stats\_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
data2 = pd.read_excel(f"C:\\Users\\Leonardo\Desktop\\Projetos Python\\Pesquisa\\trelica_secoes\\output_100.xlsx")

# %%
data2 = data2.drop('Unnamed: 0', axis = 1)
data2 = data2.drop(['Material G0', 'Material G1', 'Material G2',
       'Material G3', 'Material G4', 'Material G5', 'Material G6', 'Fx','desloc_x', 'Tension G0', 'Tension G1', 'Tension G2',
       'Tension G3', 'Tension G4', 'Tension G5', 'Tension G6', 'Fy'], axis = 1)

# %% [markdown]
# 100 EXEMPLOS

# %%
x2 = data2.drop('desloc_y', axis = 1)
y2 = data2['desloc_y']
x2_train_sm = sm.add_constant(x2)
lr2= sm.OLS(y2,x2_train_sm).fit()
print(lr2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               desloc_y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     198.9
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):           1.13e-52
# Time:                        16:44:32   Log-Likelihood:                 629.48
# No. Observations:                 100   AIC:                            -1243.
# Df Residuals:                      92   BIC:                            -1222.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0265      0.000    -62.916      0.000      -0.027      -0.026
# Section G0     6.7592      0.427     15.821      0.000       5.911       7.608
# Section G1     0.4899      0.382      1.283      0.203      -0.269       1.248
# Section G2     8.1854      0.406     20.159      0.000       7.379       8.992
# Section G3     2.9073      0.413      7.033      0.000       2.086       3.728
# Section G4     1.7207      0.390      4.408      0.000       0.945       2.496
# Section G5     3.1919      0.394      8.095      0.000       2.409       3.975
# Section G6     9.2858      0.406     22.874      0.000       8.480      10.092
# ==============================================================================
# Omnibus:                        3.761   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                3.486
# Skew:                          -0.457   Prob(JB):                        0.175
# Kurtosis:                       3.003   Cond. No.                     1.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data3 = pd.read_excel(f"C:\\Users\\Leonardo\\Desktop\\Projetos Python\\Pesquisa\\trelica_secoes\\output_1000.xlsx")
data3 = data3.drop('Unnamed: 0', axis = 1)
data3 = data3.drop(['Material G0', 'Material G1', 'Material G2',
       'Material G3', 'Material G4', 'Material G5', 'Material G6', 'Fx','desloc_x', 'Tension G0', 'Tension G1', 'Tension G2',
       'Tension G3', 'Tension G4', 'Tension G5', 'Tension G6', 'Fy'], axis = 1)

# %% [markdown]
# 1000 EXEMPLOS

# %%
x3 = data3.drop('desloc_y', axis = 1)
y3 = data3['desloc_y']
x3_train_sm = sm.add_constant(x3)
lr3= sm.OLS(y3,x3_train_sm).fit()
print(lr3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               desloc_y   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     1791.
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):               0.00
# Time:                        16:44:33   Log-Likelihood:                 6226.1
# No. Observations:                1000   AIC:                        -1.244e+04
# Df Residuals:                     992   BIC:                        -1.240e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0263      0.000   -183.294      0.000      -0.027      -0.026
# Section G0     6.6280      0.129     51.553      0.000       6.376       6.880
# Section G1     0.7006      0.132      5.320      0.000       0.442       0.959
# Section G2     7.5891      0.127     59.728      0.000       7.340       7.838
# Section G3     2.7811      0.131     21.183      0.000       2.523       3.039
# Section G4     1.9811      0.132     15.064      0.000       1.723       2.239
# Section G5     3.2416      0.128     25.255      0.000       2.990       3.493
# Section G6     9.1140      0.130     70.199      0.000       8.859       9.369
# ==============================================================================
# Omnibus:                       42.874   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.651
# Skew:                          -0.534   Prob(JB):                     4.50e-11
# Kurtosis:                       3.039   Cond. No.                     9.03e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data4 = pd.read_excel(f"C:\\Users\\Leonardo\\Desktop\\Projetos Python\\Pesquisa\\trelica_secoes\\output_50.xlsx")
data4 = data4.drop('Unnamed: 0', axis = 1)
data4 = data4.drop(['Material G0', 'Material G1', 'Material G2',
       'Material G3', 'Material G4', 'Material G5', 'Material G6', 'Fx','desloc_x', 'Tension G0', 'Tension G1', 'Tension G2',
       'Tension G3', 'Tension G4', 'Tension G5', 'Tension G6', 'Fy'], axis = 1)

# %%
x4 = data4.drop('desloc_y', axis = 1)
y4 = data4['desloc_y']
x4_train_sm = sm.add_constant(x4)
lr4= sm.OLS(y4,x4_train_sm).fit()
print(lr4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               desloc_y   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     81.33
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):           2.36e-22
# Time:                        16:44:33   Log-Likelihood:                 312.56
# No. Observations:                  50   AIC:                            -609.1
# Df Residuals:                      42   BIC:                            -593.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0263      0.001    -40.924      0.000      -0.028      -0.025
# Section G0     6.0215      0.566     10.641      0.000       4.880       7.163
# Section G1     1.3056      0.640      2.040      0.048       0.014       2.597
# Section G2     7.5724      0.602     12.570      0.000       6.357       8.788
# Section G3     2.9998      0.774      3.873      0.000       1.437       4.563
# Section G4     1.9979      0.621      3.218      0.002       0.745       3.251
# Section G5     3.2178      0.663      4.856      0.000       1.881       4.555
# Section G6     8.8517      0.712     12.434      0.000       7.415      10.288
# ==============================================================================
# Omnibus:                        1.928   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.381   Jarque-Bera (JB):                1.768
# Skew:                          -0.356   Prob(JB):                        0.413
# Kurtosis:                       2.416   Cond. No.                     1.21e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from PIL import Image
from IPython.display import display

# Carregue a imagem .jpg
imagem = Image.open(f"C:\\Users\\Leonardo\Downloads\\f2807206-1c02-4968-ac42-e99b616a697f.jpg")

# Exiba a imagem
display(imagem)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x684>
